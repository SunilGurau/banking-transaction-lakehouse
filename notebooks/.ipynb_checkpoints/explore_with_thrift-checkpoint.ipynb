# %%
! pip install pyhive thrift
# Out:
# ...
#   Using cached PyHive-0.7.0-py3-none-any.whl
# ...
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# ...
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# ...

# %%
from pyhive import hive

conn = hive.Connection(
    host="localhost",       # or spark-thriftserver hostname
    port=10000,
    username="airflow",
)

cursor = conn.cursor()

cursor.execute("SHOW DATABASES")

for row in cursor.fetchall():
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pyhive import hive
#       3 conn = hive.Connection(
#       4     host="localhost",       # or spark-thriftserver hostname
#       5     port=10000,
#       6     username="airflow",
#       7 )
#       9 cursor = conn.cursor()
#
# File /opt/conda/lib/python3.11/site-packages/pyhive/hive.py:18
#      14 from decimal import Decimal
#      15 from ssl import CERT_NONE, CERT_OPTIONAL, CERT_REQUIRED, create_default_context
# ---> 18 from TCLIService import TCLIService
#      19 from TCLIService import constants
#      20 from TCLIService import ttypes
#
# File /opt/conda/lib/python3.11/site-packages/TCLIService/TCLIService.py:9
#       1 #
#       2 # Autogenerated by Thrift Compiler (0.10.0)
#       3 #
#    (...)
#       6 #  options string: py
#       7 #
# ...
